# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_data.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
row, column = df.shape

# %%
print(row)
print(column)
# Out:
# 395
# 33

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.describe(include='all') #it will print the statistics about both numeric and categorical cols
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %%
df['school'].value_counts()
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df['address'].unique() # values in address col
# Out:
# array(['U', 'R'], dtype=object)

# %%
df['address'].nunique()
# Out:
# 2

# %%
df['famsize'].unique() # values in famsize col
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
# grouping = data.groupby('school').apply(lambda group: group[group['age'] < 15])
df.groupby(['school','sex'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %%
plt.bar(df['sex'],df['age'])
# Out:
# <BarContainer object of 395 artists>

# %%
df['address'].value_counts()
# Out:
# address
# U    307
# R     88
# Name: count, dtype: int64

# %%
def age_filter(group):
    return group[group['age'] < 18]

grouping = df.groupby("school").apply(age_filter).reset_index(drop=True)
print(grouping)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   17       U     GT3       T     1     1   at_home     other
# 1       GP   F   15       U     LE3       T     1     1   at_home     other
# 2       GP   F   15       U     GT3       T     4     2    health  services
# 3       GP   F   16       U     GT3       T     3     3     other     other
# 4       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 279     MS   F   17       U     GT3       T     2     2     other   at_home
# 280     MS   F   17       R     GT3       T     1     2     other     other
# 281     MS   F   17       R     GT3       T     3     1   at_home     other
# 282     MS   M   17       U     GT3       T     2     3     other  services
# 283     MS   M   17       U     LE3       T     3     1  services  services
#
# ...

# %%
df.groupby('sex')['age'].max()
# Out:
# sex
# F    20
# M    22
# Name: age, dtype: int64

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.groupby(['sex','school'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# sex school
# F   GP      10.579235  10.398907   9.972678
#     MS      10.920000  10.320000   9.920000
# M   GP      11.337349  11.204819  11.060241
#     MS      10.380952  10.047619   9.761905

# %%
df['Pstatus'].count()
# Out:
# 395

# %%
df['Pstatus'].value_counts()
# Out:
# Pstatus
# T    354
# A     41
# Name: count, dtype: int64

# %%
df[(df['Medu'] == 4) & (df['Mjob'] == 'at_home')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home  teacher
# 363     MS   F   17       U     LE3       T     4     4  at_home  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 363  ...      2        3      4     1     1      1        0  16  15  15
#
# [2 rows x 33 columns]

# %%
df[(df['Fedu'] == 1) & (df['Fjob']=='teacher')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 287     GP   F   17       U     GT3       T     1     1  services  teacher
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 287  ...      4        3      3     1     1      3        6  13  12  12
#
# [1 rows x 33 columns]

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
grouped_df = df.groupby('famsize')[['Mjob', 'Fjob', 'Medu', 'Fedu']].first() # the first function will print the first row for each group
grouped_df
# Out:
#             Mjob     Fjob  Medu  Fedu
# famsize
# GT3      at_home  teacher     4     4
# LE3      at_home    other     1     1

# %%
grouped_df = df.groupby('famsize')[['Mjob', 'Fjob', 'Medu', 'Fedu']].first()
grouped_df
# Out:
#             Mjob     Fjob  Medu  Fedu
# famsize
# GT3      at_home  teacher     4     4
# LE3      at_home    other     1     1

# %%
# to print the first five rows of each group
result_df = df.groupby('famsize')[['Mjob', 'Fjob', 'Medu', 'Fedu']].apply(lambda x: x.head(5))
result_df
# Out:
#                 Mjob      Fjob  Medu  Fedu
# famsize
# GT3     0    at_home   teacher     4     4
#         1    at_home     other     1     1
#         3     health  services     4     2
#         4      other     other     3     3
#         7      other   teacher     4     4
# LE3     2    at_home     other     1     1
#         5   services     other     4     3
#         6      other     other     2     2
#         8   services     other     3     2
#         12    health  services     4     4

# %%
def get_first_5_rows(x):
    return x.head(5)
result = df.groupby('famsize')[['Mjob', 'Fjob', 'Medu', 'Fedu']].apply(get_first_5_rows)
result
# Out:
#                 Mjob      Fjob  Medu  Fedu
# famsize
# GT3     0    at_home   teacher     4     4
#         1    at_home     other     1     1
#         3     health  services     4     2
#         4      other     other     3     3
#         7      other   teacher     4     4
# LE3     2    at_home     other     1     1
#         5   services     other     4     3
#         6      other     other     2     2
#         8   services     other     3     2
#         12    health  services     4     4

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
sns.histplot(df['freetime'],kde=True)
# Out:
# <Axes: xlabel='freetime', ylabel='Count'>
